# %% [markdown]
# # Olist — Late Delivery Prediction
# ## Step 1: Feature Engineering
# **Goal:** Create target variable `is_late` and engineer features for ML model.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print('Libraries loaded.')

# %%
# Load master data
df = pd.read_csv('../master_data.csv')
print(df.shape)
df.head()

# %% [markdown]
# ## Target Variable — `is_late`
# Filter delivered orders → convert date columns → create binary target.

# %%
# YOUR CODE: Filter + create is_late

# %% [markdown]
# ## Feature Engineering
# Create features for the model.

# %%
# YOUR CODE: Feature engineering
